# %% [markdown]
# <a href="https://colab.research.google.com/github/Amresh-01/Ajay_cafe/blob/master/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=b=c=5
print(a)
print(b)
# Out:
# 5
# 5

# %%
print(5//2)
print(5/2)
# Out:
# 2
# 2.5
